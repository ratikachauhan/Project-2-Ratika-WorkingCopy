# %% [markdown]
# # Import Libraries

# %%
#Dependencies
import pandas as pd
import numpy as np
import json
import os
import requests 
import pymongo

# %% [markdown]
# # Perform API CALL

# %%
#Base URL for grabbing data from City Of Chicago
base_url ="https://data.cityofchicago.org/resource/ijzp-q8t2.geojson"

#Specify the Test URL with limit and offset parameters
#test_url ="https://data.cityofchicago.org/resource/ijzp-q8t2.geojson?$limit=50000&$offset=0&$order=id&$where=year>2017"

# %% [markdown]
# ### Define query paramerters to pull data from API

# %%
#Set parameter for API Call
offset= 0
limit = 50000 #50000
year =2020
record_counter =0

# Set empty lists to hold the combined data
crime_data = []

# %% [markdown]
# ### Paging through the data using query parameters

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")
#Paging through the data using query parameters - Loop through from pages
print(f"Loading first {limit} records.")
for i in range(5):
     query_url =f"{base_url}?$limit={limit}&$offset={offset}&$order=id&year={year}"
     #query_url =f"{base_url}?$limit={limit}&$offset={offset}&$order=id&$where=year=2018"
     #query_url =f"{base_url}?$limit={limit}&$offset={offset}&$order=id&$where=(year>2017&&year<2020)"
     print(f"Loading next {limit} records.")
     response = requests.get(query_url)
     data = response.json()
     #page = requests.get(f"https://data.cityofchicago.org/resource/ijzp-q8t2.geojson?$limit={limit}&$offset={offset}&$order=id&$where=year > 2017")
     offset += limit
     #crime_data += data
     crime_data = crime_data + data['features']
     #crime_data = crime_data + data["type"]
print("-----------------------------")
print(f"Data Retrieval Complete for {year}.Received {len(crime_data)} responses.")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Loading first 50000 records.
# Loading next 50000 records.
# Loading next 50000 records.
# Loading next 50000 records.
# Loading next 50000 records.
# Loading next 50000 records.
# -----------------------------
# Data Retrieval Complete for 2020.Received 211362 responses.

# %% [markdown]
# ### Data Validation & Preprocessing - JSON File

# %%
# Check the total number of json objects recieved
print(f"We received {len(crime_data)} responses.")
# Out:
# We received 211362 responses.

# %%
# View first json object
crime_data[0]
#print(f"The first response is {json.dumps(crime_data[0], indent=2)}.")
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-87.561272312, 41.764728045]},
#  'properties': {'location_state': '',
#   'location_zip': '',
#   'x_coordinate': '1194878',
#   'domestic': False,
#   'latitude': '41.764728045',
#   'updated_on': '2020-06-20T15:48:45.000',
#   'description': 'FIRST DEGREE MURDER',
#   'location_address': '',
#   'arrest': True,
#   'location_city': '',
#   'year': '2020',
#   'longitude': '-87.561272312',
#   'block': '072XX S SOUTH SHORE DR',
#   'fbi_code': '01A',
#   'ward': '7',
#   'id': '24889',
#   'date': '2020-01-02T02:54:00.000',
#   'beat': '0334',
#   'y_coordinate': '1857803',
#   'community_area': '43',
#   'location_description': 'APARTMENT',
#   'district': '003',
#   'iucr': '0110',
#   'case_number': 'JD101272',
#   'primary_type': 'HOMICIDE'}}

# %% [markdown]
# #### Data Exploration using pandas to create summary table

# %%
#Normalizing the json objects to pandas - Validation Columns
crime_data_pd = pd.json_normalize(crime_data)
#crime_data_pd.dtypes

# %%
#Transforming trending date to datetime format
crime_data_pd['date'] = pd.to_datetime(crime_data_pd['properties.date'], format = '%Y-%m-%dT%H:%M:%S.%f')
#crime_data_pd.dtypes

# %%
#Checking for null values
print(crime_data_pd.isnull().sum())
# Out:
# type                                    0
# geometry.type                        2899
# geometry.coordinates                 2899
# properties.location_state            2899
# properties.location_zip              2899
# properties.x_coordinate              2899
# properties.domestic                     0
# properties.latitude                  2899
# properties.updated_on                   0
# properties.description                  0
# properties.location_address          2899
# properties.arrest                       0
# properties.location_city             2899
# properties.year                         0
# properties.longitude                 2899
# properties.block                        0
# properties.fbi_code                     0
# properties.ward                         9
# properties.id                           0
# properties.date                         0
# properties.beat                         0
# properties.y_coordinate              2899
# properties.community_area               1
# properties.location_description      1216
# properties.district                     0
# properties.iucr                         0
# properties.case_number                  0
# properties.primary_type                 0
# geometry                           211362
# date                                    0
# dtype: int64

# %%
crime_data_pd['crime_month'] =crime_data_pd['date'].dt.month
crime_data_pd['crime_month_name'] =crime_data_pd['date'].dt.month_name(locale='English')

# %%
#Creating a Data Frame with Selected Columns
crime_data_df = crime_data_pd[['properties.id','properties.year','crime_month','crime_month_name','properties.description','properties.location_description',
                               'properties.primary_type','properties.arrest','properties.domestic']]

# %%
crime_data_df = crime_data_df.rename(columns=
                                      { "properties.id":"id", "properties.year":"year", "properties.arrest":"arrest",
                                        "properties.primary_type":"primary_type", "properties.domestic":"domestic",
                                        "properties.description":"description", "properties.location_description":"location_description"})

# %%
crime_data_df.head()
# Out:
#       id  year  crime_month crime_month_name          description  \
# 0  24889  2020            1          January  FIRST DEGREE MURDER
# 1  24890  2020            1          January  FIRST DEGREE MURDER
# 2  24891  2020            1          January  FIRST DEGREE MURDER
# 3  24892  2020            1          January  FIRST DEGREE MURDER
# 4  24893  2020            1          January  FIRST DEGREE MURDER
#
#   location_description primary_type  arrest  domestic
# 0            APARTMENT     HOMICIDE    True     False
# 1            APARTMENT     HOMICIDE    True     False
# 2               STREET     HOMICIDE    True     False
# 3               STREET     HOMICIDE   False     False
# 4         RETAIL STORE     HOMICIDE    True     False

# %%
#crime_count= crime_data_df.groupby(['year','crime_month_name','primary_type','description'])['id'].count()
crime_count= crime_data_df.groupby(['crime_month_name','primary_type'])['id'].count()
crime_type_summary = pd.DataFrame({'reported_crime':crime_count})
crime_type_summary =crime_type_summary.reset_index()

# %%
crime_type_dict =crime_type_summary.to_dict('records')
#crime_type_dict
f = open("../static/summary.json", "w")
json.dump(crime_type_dict, f)
f.close()

# %% [markdown]
# ### Loading Data to MONGODB  Database

# %% [markdown]
# #### Cleaning the raw json by removing extra columns

# %%
# Get rid of unnecessary columns
for property in crime_data:
    properties = (property['properties'])
    del (properties['iucr'])
    del (properties['updated_on'])
    del (properties['fbi_code'])
    del (properties['case_number'])
    del (properties['ward'])   
    del (properties['beat'])
    del (properties['community_area'])
    del (properties['location_zip'])
    del (properties['location_city'])

# %%
crime_data[0]
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-87.561272312, 41.764728045]},
#  'properties': {'location_state': '',
#   'x_coordinate': '1194878',
#   'domestic': False,
#   'latitude': '41.764728045',
#   'description': 'FIRST DEGREE MURDER',
#   'location_address': '',
#   'arrest': True,
#   'year': '2020',
#   'longitude': '-87.561272312',
#   'block': '072XX S SOUTH SHORE DR',
#   'id': '24889',
#   'date': '2020-01-02T02:54:00.000',
#   'y_coordinate': '1857803',
#   'location_description': 'APARTMENT',
#   'district': '003',
#   'primary_type': 'HOMICIDE'}}

# %%
conn = 'mongodb://localhost:27017'
#conn = 'mongodb+srv://chicago_crime_user:chicago_crime_password@cluster0.opshg.mongodb.net/CHICAGO_CRIME_GROUPPROJECT?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)

# Define the database in Mongo
db = client.chicago_crime

# %%
collection = db.events

# %%
collection.insert_many(crime_data)

# %%
# query the classroom collection in flask application
#classroom = db.classroom.find()
crime = collection.find()

# %%
crime.count()
# Out:
# <ipython-input-22-c7bd921b95df>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   crime.count()
# 211362

# %% [markdown]
# ### Loading Crime Type Dictonary in Mongo Shared

# %%
#conn = 'mongodb+srv://chicago_crime_user:chicago_crime_password@cluster0.opshg.mongodb.net/CHICAGO_CRIME_GROUPPROJECT?retryWrites=true&w=majority'
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the database in Mongo
db = client.chicago_crime

# %%
collection = db.crime_type_summary

# %%
collection.insert_many(crime_type_dict)

# %% [markdown]
# ## Jay time

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the database in Mongo
db = client.chicago_crime.crime_type_summary

type(list(db.find()))
# Out:
# list

# %%
# [
#     {'_id': ObjectId('617b40775dd8891e00990d3e'),
#         'crime_month_name': 'April',
#   'primary_type': 'ARSON',
#   'reported_crime': 35},
#     {'_id': ObjectId('617b40775dd8891e00990d3e'),
#         'crime_month_name': 'April',
#   'primary_type': 'ARSON',
#   'reported_crime': 35}
# ]

# %%
data = db.find() # for scripting is okay
data = list(db.find()) # for jupyter testing purposes

# new_data = []
# for dictionary in data:
#     placeholder_dict = {}
#     for k,v in dictionary.items():
#         if k != '_id':
#             placeholder_dict[k] = v
#     new_data.append(placeholder_list)

# print(new_data)

placeholder_dict = {}
for k,v in dictionary.items():
    if k != '_id':
        placeholder_dict[k] = v
placeholder_dict
# Out:
# {'crime_month_name': 'September',
#  'primary_type': 'WEAPONS VIOLATION',
#  'reported_crime': 831}

# %%
new_data = []

for dictionary in data:
    new_d = {k:v for k,v in dictionary.items() if k != '_id'}
    new_data.append(new_d)

new_data = [{k:v for k,v in dictionary.items() if k != '_id'} for dictionary in data]
print(new_data)
# Out:
# [{'crime_month_name': 'April', 'primary_type': 'ARSON', 'reported_crime': 35}, {'crime_month_name': 'April', 'primary_type': 'ASSAULT', 'reported_crime': 1112}, {'crime_month_name': 'April', 'primary_type': 'BATTERY', 'reported_crime': 2693}, {'crime_month_name': 'April', 'primary_type': 'BURGLARY', 'reported_crime': 527}, {'crime_month_name': 'April', 'primary_type': 'CONCEALED CARRY LICENSE VIOLATION', 'reported_crime': 7}, {'crime_month_name': 'April', 'primary_type': 'CRIMINAL DAMAGE', 'reported_crime': 1782}, {'crime_month_name': 'April', 'primary_type': 'CRIMINAL SEXUAL ASSAULT', 'reported_crime': 60}, {'crime_month_name': 'April', 'primary_type': 'CRIMINAL TRESPASS', 'reported_crime': 235}, {'crime_month_name': 'April', 'primary_type': 'DECEPTIVE PRACTICE', 'reported_crime': 1091}, {'crime_month_name': 'April', 'primary_type': 'HOMICIDE', 'reported_crime': 62}, {'crime_month_name': 'April', 'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER', 'reported_crime': 17}, {'crime_month_name': 'April', 'primary_type': 'INTIMIDATION', 'reported_crime': 4}, {'crime_month_name': 'April', 'primary_type': 'KIDNAPPING', 'reported_crime': 3}, {'crime_month_name': 'April', 'primary_type': 'LIQUOR LAW VIOLATION', 'reported_crime': 1}, {'crime_month_name': 'April', 'primary_type': 'MOTOR VEHICLE THEFT', 'reported_crime': 659}, {'crime_month_name': 'April', 'primary_type': 'NARCOTICS', 'reported_crime': 179}, {'crime_month_name': 'April', 'primary_type': 'OBSCENITY', 'reported_crime': 4}, {'crime_month_name': 'April', 'primary_type': 'OFFENSE INVOLVING CHILDREN', 'reported_crime': 128}, {'crime_month_name': 'April', 'primary_type': 'OTHER OFFENSE', 'reported_crime': 742}, {'crime_month_name': 'April', 'primary_type': 'PROSTITUTION', 'reported_crime': 2}, {'crime_month_name': 'April', 'primary_type': 'PUBLIC PEACE VIOLATION', 'reported_crime': 39}, {'crime_month_name': 'April', 'primary_type': 'ROBBERY', 'reported_crime': 455}, {'crime_month_name': 'April', 'primary_type': 'SEX OFFENSE', 'reported_crime': 58}, {'crime_month_name': 'April', 'primary_type': 'STALKING', 'reported_crime': 8}, {'crime_month_name': 'April', 'primary_type': 'THEFT', 'reported_crime': 2500}, {'crime_month_name': 'April', 'primary_type': 'WEAPONS VIOLATION', 'reported_crime': 474}, {'crime_month_name': 'August', 'primary_type': 'ARSON', 'reported_crime': 57}, {'crime_month_name': 'August', 'primary_type': 'ASSAULT', 'reported_crime': 1835}, {'crime_month_name': 'August', 'primary_type': 'BATTERY', 'reported_crime': 4073}, {'crime_month_name': 'August', 'primary_type': 'BURGLARY', 'reported_crime': 1062}, {'crime_month_name': 'August', 'primary_type': 'CONCEALED CARRY LICENSE VIOLATION', 'reported_crime': 11}, {'crime_month_name': 'August', 'primary_type': 'CRIMINAL DAMAGE', 'reported_crime': 2364}, {'crime_month_name': 'August', 'primary_type': 'CRIMINAL SEXUAL ASSAULT', 'reported_crime': 106}, {'crime_month_name': 'August', 'primary_type': 'CRIMINAL TRESPASS', 'reported_crime': 342}, {'crime_month_name': 'August', 'primary_type': 'DECEPTIVE PRACTICE', 'reported_crime': 1159}, {'crime_month_name': 'August', 'primary_type': 'GAMBLING', 'reported_crime': 3}, {'crime_month_name': 'August', 'primary_type': 'HOMICIDE', 'reported_crime': 67}, {'crime_month_name': 'August', 'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER', 'reported_crime': 50}, {'crime_month_name': 'August', 'primary_type': 'INTIMIDATION', 'reported_crime': 15}, {'crime_month_name': 'August', 'primary_type': 'KIDNAPPING', 'reported_crime': 11}, {'crime_month_name': 'August', 'primary_type': 'LIQUOR LAW VIOLATION', 'reported_crime': 28}, {'crime_month_name': 'August', 'primary_type': 'MOTOR VEHICLE THEFT', 'reported_crime': 997}, {'crime_month_name': 'August', 'primary_type': 'NARCOTICS', 'reported_crime': 552}, {'crime_month_name': 'August', 'primary_type': 'NON-CRIMINAL', 'reported_crime': 1}, {'crime_month_name': 'August', 'primary_type': 'OBSCENITY', 'reported_crime': 5}, {'crime_month_name': 'August ...

# %%
list(db.find())
# Out:
# [{'_id': ObjectId('617b40775dd8891e00990d3e'),
#   'crime_month_name': 'April',
#   'primary_type': 'ARSON',
#   'reported_crime': 35},
#  {'_id': ObjectId('617b40775dd8891e00990d3f'),
#   'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1112},
#  {'_id': ObjectId('617b40775dd8891e00990d40'),
#   'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'reported_crime': 2693},
#  {'_id': ObjectId('617b40775dd8891e00990d41'),
#   'crime_month_name': 'April',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 527},
#  {'_id': ObjectId('617b40775dd8891e00990d42'),
#   'crime_month_name': 'April',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 7},
#  {'_id': ObjectId('617b40775dd8891e00990d43'),
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1782},
#  {'_id': ObjectId('617b40775dd8891e00990d44'),
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 60},
#  {'_id': ObjectId('617b40775dd8891e00990d45'),
#   'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 235},
#  {'_id': ObjectId('617b40775dd8891e00990d46'),
#   'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1091},
#  {'_id': ObjectId('617b40775dd8891e00990d47'),
#   'crime_month_name': 'April',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 62},
#  {'_id': ObjectId('617b40775dd8891e00990d48'),
#   'crime_month_name': 'April',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 17},
#  {'_id': ObjectId('617b40775dd8891e00990d49'),
#   'crime_month_name': 'April',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 4},
#  {'_id': ObjectId('617b40775dd8891e00990d4a'),
#   'crime_month_name': 'April',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 3},
#  {'_id': ObjectId('617b40775dd8891e00990d4b'),
#   'crime_month_name': 'April',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990d4c'),
#   'crime_month_name': 'April',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 659},
#  {'_id': ObjectId('617b40775dd8891e00990d4d'),
#   'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 179},
#  {'_id': ObjectId('617b40775dd8891e00990d4e'),
#   'crime_month_name': 'April',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 4},
#  {'_id': ObjectId('617b40775dd8891e00990d4f'),
#   'crime_month_name': 'April',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 128},
#  {'_id': ObjectId('617b40775dd8891e00990d50'),
#   'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 742},
#  {'_id': ObjectId('617b40775dd8891e00990d51'),
#   'crime_month_name': 'April',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 2},
#  {'_id': ObjectId('617b40775dd8891e00990d52'),
#   'crime_month_name': 'April',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 39},
#  {'_id': ObjectId('617b40775dd8891e00990d53'),
#   'crime_month_name': 'April',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 455},
#  {'_id': ObjectId('617b40775dd8891e00990d54'),
#   'crime_month_name': 'April',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 58},
#  {'_id': ObjectId('617b40775dd8891e00990d55'),
#   'crime_month_name': 'April',
#   'primary_type': 'STALKING',
#   'reported_crime': 8},
#  {'_id': ObjectId('617b40775dd8891e00990d56'),
#   'crime_month_name': 'April',
#   'primary_type': 'THEFT',
#   'reported_crime': 2500},
#  {'_id': ObjectId('617b40775dd8891e00990d57'),
#   'crime_month_name': 'April',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 474},
#  {'_id': ObjectId('617b40775dd8891e00990d58'),
#   'crime_month_name': 'August',
#   'primary_type': 'ARSON',
#   'reported_crime': 57},
#  {'_id': ObjectId('617b40775dd8891e00990d59'),
#   'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1835},
#  {'_id': ObjectId('617b40775dd8891e00990d5a'),
#   'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'reported_crime': 4073},
#  {'_id': ObjectId('617b40775dd8891e00990d5b'),
#   'crime_month_name': 'August',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 1062},
#  {'_id': ObjectId('617b40775dd8891e00990d5c'),
#   'crime_month_name': 'August',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 11},
#  {'_id': ObjectId('617b40775dd8891e00990d5d'),
#   'crime_month_name': 'August',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 2364},
#  {'_id': ObjectId('617b40775dd8891e00990d5e'),
#   'crime_month_name': 'August',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 106},
#  {'_id': ObjectId('617b40775dd8891e00990d5f'),
#   'crime_month_name': 'August',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 342},
#  {'_id': ObjectId('617b40775dd8891e00990d60'),
#   'crime_month_name': 'August',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1159},
#  {'_id': ObjectId('617b40775dd8891e00990d61'),
#   'crime_month_name': 'August',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 3},
#  {'_id': ObjectId('617b40775dd8891e00990d62'),
#   'crime_month_name': 'August',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 67},
#  {'_id': ObjectId('617b40775dd8891e00990d63'),
#   'crime_month_name': 'August',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 50},
#  {'_id': ObjectId('617b40775dd8891e00990d64'),
#   'crime_month_name': 'August',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 15},
#  {'_id': ObjectId('617b40775dd8891e00990d65'),
#   'crime_month_name': 'August',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 11},
#  {'_id': ObjectId('617b40775dd8891e00990d66'),
#   'crime_month_name': 'August',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 28},
#  {'_id': ObjectId('617b40775dd8891e00990d67'),
#   'crime_month_name': 'August',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 997},
#  {'_id': ObjectId('617b40775dd8891e00990d68'),
#   'crime_month_name': 'August',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 552},
#  {'_id': ObjectId('617b40775dd8891e00990d69'),
#   'crime_month_name': 'August',
#   'primary_type': 'NON-CRIMINAL',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990d6a'),
#   'crime_month_name': 'August',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 5},
#  {'_id': ObjectId('617b40775dd8891e00990d6b'),
#   'crime_month_name': 'August',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 122},
#  {'_id': ObjectId('617b40775dd8891e00990d6c'),
#   'crime_month_name': 'August',
#   'primary_type': 'OTHER NARCOTIC VIOLATION',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990d6d'),
#   'crime_month_name': 'August',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1096},
#  {'_id': ObjectId('617b40775dd8891e00990d6e'),
#   'crime_month_name': 'August',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 9},
#  {'_id': ObjectId('617b40775dd8891e00990d6f'),
#   'crime_month_name': 'August',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 2},
#  {'_id': ObjectId('617b40775dd8891e00990d70'),
#   'crime_month_name': 'August',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 92},
#  {'_id': ObjectId('617b40775dd8891e00990d71'),
#   'crime_month_name': 'August',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 816},
#  {'_id': ObjectId('617b40775dd8891e00990d72'),
#   'crime_month_name': 'August',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 93},
#  {'_id': ObjectId('617b40775dd8891e00990d73'),
#   'crime_month_name': 'August',
#   'primary_type': 'STALKING',
#   'reported_crime': 23},
#  {'_id': ObjectId('617b40775dd8891e00990d74'),
#   'crime_month_name': 'August',
#   'primary_type': 'THEFT',
#   'reported_crime': 3879},
#  {'_id': ObjectId('617b40775dd8891e00990d75'),
#   'crime_month_name': 'August',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 983},
#  {'_id': ObjectId('617b40775dd8891e00990d76'),
#   'crime_month_name': 'December',
#   'primary_type': 'ARSON',
#   'reported_crime': 40},
#  {'_id': ObjectId('617b40775dd8891e00990d77'),
#   'crime_month_name': 'December',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1273},
#  {'_id': ObjectId('617b40775dd8891e00990d78'),
#   'crime_month_name': 'December',
#   'primary_type': 'BATTERY',
#   'reported_crime': 2729},
#  {'_id': ObjectId('617b40775dd8891e00990d79'),
#   'crime_month_name': 'December',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 546},
#  {'_id': ObjectId('617b40775dd8891e00990d7a'),
#   'crime_month_name': 'December',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 8},
#  {'_id': ObjectId('617b40775dd8891e00990d7b'),
#   'crime_month_name': 'December',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1670},
#  {'_id': ObjectId('617b40775dd8891e00990d7c'),
#   'crime_month_name': 'December',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 71},
#  {'_id': ObjectId('617b40775dd8891e00990d7d'),
#   'crime_month_name': 'December',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 265},
#  {'_id': ObjectId('617b40775dd8891e00990d7e'),
#   'crime_month_name': 'December',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 2819},
#  {'_id': ObjectId('617b40775dd8891e00990d7f'),
#   'crime_month_name': 'December',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 55},
#  {'_id': ObjectId('617b40775dd8891e00990d80'),
#   'crime_month_name': 'December',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 40},
#  {'_id': ObjectId('617b40775dd8891e00990d81'),
#   'crime_month_name': 'December',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 6},
#  {'_id': ObjectId('617b40775dd8891e00990d82'),
#   'crime_month_name': 'December',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 6},
#  {'_id': ObjectId('617b40775dd8891e00990d83'),
#   'crime_month_name': 'December',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 4},
#  {'_id': ObjectId('617b40775dd8891e00990d84'),
#   'crime_month_name': 'December',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 909},
#  {'_id': ObjectId('617b40775dd8891e00990d85'),
#   'crime_month_name': 'December',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 514},
#  {'_id': ObjectId('617b40775dd8891e00990d86'),
#   'crime_month_name': 'December',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 3},
#  {'_id': ObjectId('617b40775dd8891e00990d87'),
#   'crime_month_name': 'December',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 162},
#  {'_id': ObjectId('617b40775dd8891e00990d88'),
#   'crime_month_name': 'December',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 932},
#  {'_id': ObjectId('617b40775dd8891e00990d89'),
#   'crime_month_name': 'December',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 4},
#  {'_id': ObjectId('617b40775dd8891e00990d8a'),
#   'crime_month_name': 'December',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 45},
#  {'_id': ObjectId('617b40775dd8891e00990d8b'),
#   'crime_month_name': 'December',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 565},
#  {'_id': ObjectId('617b40775dd8891e00990d8c'),
#   'crime_month_name': 'December',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 55},
#  {'_id': ObjectId('617b40775dd8891e00990d8d'),
#   'crime_month_name': 'December',
#   'primary_type': 'STALKING',
#   'reported_crime': 15},
#  {'_id': ObjectId('617b40775dd8891e00990d8e'),
#   'crime_month_name': 'December',
#   'primary_type': 'THEFT',
#   'reported_crime': 2910},
#  {'_id': ObjectId('617b40775dd8891e00990d8f'),
#   'crime_month_name': 'December',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 765},
#  {'_id': ObjectId('617b40775dd8891e00990d90'),
#   'crime_month_name': 'February',
#   'primary_type': 'ARSON',
#   'reported_crime': 31},
#  {'_id': ObjectId('617b40775dd8891e00990d91'),
#   'crime_month_name': 'February',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1386},
#  {'_id': ObjectId('617b40775dd8891e00990d92'),
#   'crime_month_name': 'February',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3386},
#  {'_id': ObjectId('617b40775dd8891e00990d93'),
#   'crime_month_name': 'February',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 618},
#  {'_id': ObjectId('617b40775dd8891e00990d94'),
#   'crime_month_name': 'February',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 13},
#  {'_id': ObjectId('617b40775dd8891e00990d95'),
#   'crime_month_name': 'February',
#   'primary_type': 'CRIM SEXUAL ASSAULT',
#   'reported_crime': 22},
#  {'_id': ObjectId('617b40775dd8891e00990d96'),
#   'crime_month_name': 'February',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1742},
#  {'_id': ObjectId('617b40775dd8891e00990d97'),
#   'crime_month_name': 'February',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 94},
#  {'_id': ObjectId('617b40775dd8891e00990d98'),
#   'crime_month_name': 'February',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 535},
#  {'_id': ObjectId('617b40775dd8891e00990d99'),
#   'crime_month_name': 'February',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1351},
#  {'_id': ObjectId('617b40775dd8891e00990d9a'),
#   'crime_month_name': 'February',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 38},
#  {'_id': ObjectId('617b40775dd8891e00990d9b'),
#   'crime_month_name': 'February',
#   'primary_type': 'HUMAN TRAFFICKING',
#   'reported_crime': 2},
#  {'_id': ObjectId('617b40775dd8891e00990d9c'),
#   'crime_month_name': 'February',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 116},
#  {'_id': ObjectId('617b40775dd8891e00990d9d'),
#   'crime_month_name': 'February',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 13},
#  {'_id': ObjectId('617b40775dd8891e00990d9e'),
#   'crime_month_name': 'February',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 11},
#  {'_id': ObjectId('617b40775dd8891e00990d9f'),
#   'crime_month_name': 'February',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 21},
#  {'_id': ObjectId('617b40775dd8891e00990da0'),
#   'crime_month_name': 'February',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 652},
#  {'_id': ObjectId('617b40775dd8891e00990da1'),
#   'crime_month_name': 'February',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 1177},
#  {'_id': ObjectId('617b40775dd8891e00990da2'),
#   'crime_month_name': 'February',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 2},
#  {'_id': ObjectId('617b40775dd8891e00990da3'),
#   'crime_month_name': 'February',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 204},
#  {'_id': ObjectId('617b40775dd8891e00990da4'),
#   'crime_month_name': 'February',
#   'primary_type': 'OTHER NARCOTIC VIOLATION',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990da5'),
#   'crime_month_name': 'February',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1243},
#  {'_id': ObjectId('617b40775dd8891e00990da6'),
#   'crime_month_name': 'February',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 27},
#  {'_id': ObjectId('617b40775dd8891e00990da7'),
#   'crime_month_name': 'February',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 2},
#  {'_id': ObjectId('617b40775dd8891e00990da8'),
#   'crime_month_name': 'February',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 87},
#  {'_id': ObjectId('617b40775dd8891e00990da9'),
#   'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 637},
#  {'_id': ObjectId('617b40775dd8891e00990daa'),
#   'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 90},
#  {'_id': ObjectId('617b40775dd8891e00990dab'),
#   'crime_month_name': 'February',
#   'primary_type': 'STALKING',
#   'reported_crime': 18},
#  {'_id': ObjectId('617b40775dd8891e00990dac'),
#   'crime_month_name': 'February',
#   'primary_type': 'THEFT',
#   'reported_crime': 4176},
#  {'_id': ObjectId('617b40775dd8891e00990dad'),
#   'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 461},
#  {'_id': ObjectId('617b40775dd8891e00990dae'),
#   'crime_month_name': 'January',
#   'primary_type': 'ARSON',
#   'reported_crime': 23},
#  {'_id': ObjectId('617b40775dd8891e00990daf'),
#   'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1519},
#  {'_id': ObjectId('617b40775dd8891e00990db0'),
#   'crime_month_name': 'January',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3606},
#  {'_id': ObjectId('617b40775dd8891e00990db1'),
#   'crime_month_name': 'January',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 740},
#  {'_id': ObjectId('617b40775dd8891e00990db2'),
#   'crime_month_name': 'January',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 15},
#  {'_id': ObjectId('617b40775dd8891e00990db3'),
#   'crime_month_name': 'January',
#   'primary_type': 'CRIM SEXUAL ASSAULT',
#   'reported_crime': 53},
#  {'_id': ObjectId('617b40775dd8891e00990db4'),
#   'crime_month_name': 'January',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1791},
#  {'_id': ObjectId('617b40775dd8891e00990db5'),
#   'crime_month_name': 'January',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 96},
#  {'_id': ObjectId('617b40775dd8891e00990db6'),
#   'crime_month_name': 'January',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 575},
#  {'_id': ObjectId('617b40775dd8891e00990db7'),
#   'crime_month_name': 'January',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1542},
#  {'_id': ObjectId('617b40775dd8891e00990db8'),
#   'crime_month_name': 'January',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 2},
#  {'_id': ObjectId('617b40775dd8891e00990db9'),
#   'crime_month_name': 'January',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 36},
#  {'_id': ObjectId('617b40775dd8891e00990dba'),
#   'crime_month_name': 'January',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 121},
#  {'_id': ObjectId('617b40775dd8891e00990dbb'),
#   'crime_month_name': 'January',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 9},
#  {'_id': ObjectId('617b40775dd8891e00990dbc'),
#   'crime_month_name': 'January',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 14},
#  {'_id': ObjectId('617b40775dd8891e00990dbd'),
#   'crime_month_name': 'January',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 15},
#  {'_id': ObjectId('617b40775dd8891e00990dbe'),
#   'crime_month_name': 'January',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 668},
#  {'_id': ObjectId('617b40775dd8891e00990dbf'),
#   'crime_month_name': 'January',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 1292},
#  {'_id': ObjectId('617b40775dd8891e00990dc0'),
#   'crime_month_name': 'January',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 6},
#  {'_id': ObjectId('617b40775dd8891e00990dc1'),
#   'crime_month_name': 'January',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 218},
#  {'_id': ObjectId('617b40775dd8891e00990dc2'),
#   'crime_month_name': 'January',
#   'primary_type': 'OTHER NARCOTIC VIOLATION',
#   'reported_crime': 2},
#  {'_id': ObjectId('617b40775dd8891e00990dc3'),
#   'crime_month_name': 'January',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1419},
#  {'_id': ObjectId('617b40775dd8891e00990dc4'),
#   'crime_month_name': 'January',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 38},
#  {'_id': ObjectId('617b40775dd8891e00990dc5'),
#   'crime_month_name': 'January',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 107},
#  {'_id': ObjectId('617b40775dd8891e00990dc6'),
#   'crime_month_name': 'January',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 725},
#  {'_id': ObjectId('617b40775dd8891e00990dc7'),
#   'crime_month_name': 'January',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 92},
#  {'_id': ObjectId('617b40775dd8891e00990dc8'),
#   'crime_month_name': 'January',
#   'primary_type': 'STALKING',
#   'reported_crime': 13},
#  {'_id': ObjectId('617b40775dd8891e00990dc9'),
#   'crime_month_name': 'January',
#   'primary_type': 'THEFT',
#   'reported_crime': 4600},
#  {'_id': ObjectId('617b40775dd8891e00990dca'),
#   'crime_month_name': 'January',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 490},
#  {'_id': ObjectId('617b40775dd8891e00990dcb'),
#   'crime_month_name': 'July',
#   'primary_type': 'ARSON',
#   'reported_crime': 63},
#  {'_id': ObjectId('617b40775dd8891e00990dcc'),
#   'crime_month_name': 'July',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1890},
#  {'_id': ObjectId('617b40775dd8891e00990dcd'),
#   'crime_month_name': 'July',
#   'primary_type': 'BATTERY',
#   'reported_crime': 4149},
#  {'_id': ObjectId('617b40775dd8891e00990dce'),
#   'crime_month_name': 'July',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 737},
#  {'_id': ObjectId('617b40775dd8891e00990dcf'),
#   'crime_month_name': 'July',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 14},
#  {'_id': ObjectId('617b40775dd8891e00990dd0'),
#   'crime_month_name': 'July',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 2503},
#  {'_id': ObjectId('617b40775dd8891e00990dd1'),
#   'crime_month_name': 'July',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 113},
#  {'_id': ObjectId('617b40775dd8891e00990dd2'),
#   'crime_month_name': 'July',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 308},
#  {'_id': ObjectId('617b40775dd8891e00990dd3'),
#   'crime_month_name': 'July',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1347},
#  {'_id': ObjectId('617b40775dd8891e00990dd4'),
#   'crime_month_name': 'July',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 2},
#  {'_id': ObjectId('617b40775dd8891e00990dd5'),
#   'crime_month_name': 'July',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 111},
#  {'_id': ObjectId('617b40775dd8891e00990dd6'),
#   'crime_month_name': 'July',
#   'primary_type': 'HUMAN TRAFFICKING',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990dd7'),
#   'crime_month_name': 'July',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 43},
#  {'_id': ObjectId('617b40775dd8891e00990dd8'),
#   'crime_month_name': 'July',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 21},
#  {'_id': ObjectId('617b40775dd8891e00990dd9'),
#   'crime_month_name': 'July',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 8},
#  {'_id': ObjectId('617b40775dd8891e00990dda'),
#   'crime_month_name': 'July',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 29},
#  {'_id': ObjectId('617b40775dd8891e00990ddb'),
#   'crime_month_name': 'July',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 957},
#  {'_id': ObjectId('617b40775dd8891e00990ddc'),
#   'crime_month_name': 'July',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 517},
#  {'_id': ObjectId('617b40775dd8891e00990ddd'),
#   'crime_month_name': 'July',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 7},
#  {'_id': ObjectId('617b40775dd8891e00990dde'),
#   'crime_month_name': 'July',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 164},
#  {'_id': ObjectId('617b40775dd8891e00990ddf'),
#   'crime_month_name': 'July',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1113},
#  {'_id': ObjectId('617b40775dd8891e00990de0'),
#   'crime_month_name': 'July',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 80},
#  {'_id': ObjectId('617b40775dd8891e00990de1'),
#   'crime_month_name': 'July',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 77},
#  {'_id': ObjectId('617b40775dd8891e00990de2'),
#   'crime_month_name': 'July',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 734},
#  {'_id': ObjectId('617b40775dd8891e00990de3'),
#   'crime_month_name': 'July',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 100},
#  {'_id': ObjectId('617b40775dd8891e00990de4'),
#   'crime_month_name': 'July',
#   'primary_type': 'STALKING',
#   'reported_crime': 16},
#  {'_id': ObjectId('617b40775dd8891e00990de5'),
#   'crime_month_name': 'July',
#   'primary_type': 'THEFT',
#   'reported_crime': 3662},
#  {'_id': ObjectId('617b40775dd8891e00990de6'),
#   'crime_month_name': 'July',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 804},
#  {'_id': ObjectId('617b40775dd8891e00990de7'),
#   'crime_month_name': 'June',
#   'primary_type': 'ARSON',
#   'reported_crime': 74},
#  {'_id': ObjectId('617b40775dd8891e00990de8'),
#   'crime_month_name': 'June',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1724},
#  {'_id': ObjectId('617b40775dd8891e00990de9'),
#   'crime_month_name': 'June',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3919},
#  {'_id': ObjectId('617b40775dd8891e00990dea'),
#   'crime_month_name': 'June',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 753},
#  {'_id': ObjectId('617b40775dd8891e00990deb'),
#   'crime_month_name': 'June',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 13},
#  {'_id': ObjectId('617b40775dd8891e00990dec'),
#   'crime_month_name': 'June',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 2449},
#  {'_id': ObjectId('617b40775dd8891e00990ded'),
#   'crime_month_name': 'June',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 99},
#  {'_id': ObjectId('617b40775dd8891e00990dee'),
#   'crime_month_name': 'June',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 284},
#  {'_id': ObjectId('617b40775dd8891e00990def'),
#   'crime_month_name': 'June',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1117},
#  {'_id': ObjectId('617b40775dd8891e00990df0'),
#   'crime_month_name': 'June',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 6},
#  {'_id': ObjectId('617b40775dd8891e00990df1'),
#   'crime_month_name': 'June',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 94},
#  {'_id': ObjectId('617b40775dd8891e00990df2'),
#   'crime_month_name': 'June',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 28},
#  {'_id': ObjectId('617b40775dd8891e00990df3'),
#   'crime_month_name': 'June',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 22},
#  {'_id': ObjectId('617b40775dd8891e00990df4'),
#   'crime_month_name': 'June',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 14},
#  {'_id': ObjectId('617b40775dd8891e00990df5'),
#   'crime_month_name': 'June',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990df6'),
#   'crime_month_name': 'June',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 794},
#  {'_id': ObjectId('617b40775dd8891e00990df7'),
#   'crime_month_name': 'June',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 338},
#  {'_id': ObjectId('617b40775dd8891e00990df8'),
#   'crime_month_name': 'June',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 6},
#  {'_id': ObjectId('617b40775dd8891e00990df9'),
#   'crime_month_name': 'June',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 153},
#  {'_id': ObjectId('617b40775dd8891e00990dfa'),
#   'crime_month_name': 'June',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 963},
#  {'_id': ObjectId('617b40775dd8891e00990dfb'),
#   'crime_month_name': 'June',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 31},
#  {'_id': ObjectId('617b40775dd8891e00990dfc'),
#   'crime_month_name': 'June',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 156},
#  {'_id': ObjectId('617b40775dd8891e00990dfd'),
#   'crime_month_name': 'June',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 574},
#  {'_id': ObjectId('617b40775dd8891e00990dfe'),
#   'crime_month_name': 'June',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 86},
#  {'_id': ObjectId('617b40775dd8891e00990dff'),
#   'crime_month_name': 'June',
#   'primary_type': 'STALKING',
#   'reported_crime': 22},
#  {'_id': ObjectId('617b40775dd8891e00990e00'),
#   'crime_month_name': 'June',
#   'primary_type': 'THEFT',
#   'reported_crime': 3075},
#  {'_id': ObjectId('617b40775dd8891e00990e01'),
#   'crime_month_name': 'June',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 782},
#  {'_id': ObjectId('617b40775dd8891e00990e02'),
#   'crime_month_name': 'March',
#   'primary_type': 'ARSON',
#   'reported_crime': 27},
#  {'_id': ObjectId('617b40775dd8891e00990e03'),
#   'crime_month_name': 'March',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1476},
#  {'_id': ObjectId('617b40775dd8891e00990e04'),
#   'crime_month_name': 'March',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3560},
#  {'_id': ObjectId('617b40775dd8891e00990e05'),
#   'crime_month_name': 'March',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 567},
#  {'_id': ObjectId('617b40775dd8891e00990e06'),
#   'crime_month_name': 'March',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 11},
#  {'_id': ObjectId('617b40775dd8891e00990e07'),
#   'crime_month_name': 'March',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1892},
#  {'_id': ObjectId('617b40775dd8891e00990e08'),
#   'crime_month_name': 'March',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 106},
#  {'_id': ObjectId('617b40775dd8891e00990e09'),
#   'crime_month_name': 'March',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 394},
#  {'_id': ObjectId('617b40775dd8891e00990e0a'),
#   'crime_month_name': 'March',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1181},
#  {'_id': ObjectId('617b40775dd8891e00990e0b'),
#   'crime_month_name': 'March',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 4},
#  {'_id': ObjectId('617b40775dd8891e00990e0c'),
#   'crime_month_name': 'March',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 29},
#  {'_id': ObjectId('617b40775dd8891e00990e0d'),
#   'crime_month_name': 'March',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 81},
#  {'_id': ObjectId('617b40775dd8891e00990e0e'),
#   'crime_month_name': 'March',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 7},
#  {'_id': ObjectId('617b40775dd8891e00990e0f'),
#   'crime_month_name': 'March',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 8},
#  {'_id': ObjectId('617b40775dd8891e00990e10'),
#   'crime_month_name': 'March',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 11},
#  {'_id': ObjectId('617b40775dd8891e00990e11'),
#   'crime_month_name': 'March',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 628},
#  {'_id': ObjectId('617b40775dd8891e00990e12'),
#   'crime_month_name': 'March',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 741},
#  {'_id': ObjectId('617b40775dd8891e00990e13'),
#   'crime_month_name': 'March',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 2},
#  {'_id': ObjectId('617b40775dd8891e00990e14'),
#   'crime_month_name': 'March',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 161},
#  {'_id': ObjectId('617b40775dd8891e00990e15'),
#   'crime_month_name': 'March',
#   'primary_type': 'OTHER NARCOTIC VIOLATION',
#   'reported_crime': 2},
#  {'_id': ObjectId('617b40775dd8891e00990e16'),
#   'crime_month_name': 'March',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1110},
#  {'_id': ObjectId('617b40775dd8891e00990e17'),
#   'crime_month_name': 'March',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 19},
#  {'_id': ObjectId('617b40775dd8891e00990e18'),
#   'crime_month_name': 'March',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990e19'),
#   'crime_month_name': 'March',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 80},
#  {'_id': ObjectId('617b40775dd8891e00990e1a'),
#   'crime_month_name': 'March',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 495},
#  {'_id': ObjectId('617b40775dd8891e00990e1b'),
#   'crime_month_name': 'March',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 84},
#  {'_id': ObjectId('617b40775dd8891e00990e1c'),
#   'crime_month_name': 'March',
#   'primary_type': 'STALKING',
#   'reported_crime': 20},
#  {'_id': ObjectId('617b40775dd8891e00990e1d'),
#   'crime_month_name': 'March',
#   'primary_type': 'THEFT',
#   'reported_crime': 3525},
#  {'_id': ObjectId('617b40775dd8891e00990e1e'),
#   'crime_month_name': 'March',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 464},
#  {'_id': ObjectId('617b40775dd8891e00990e1f'),
#   'crime_month_name': 'May',
#   'primary_type': 'ARSON',
#   'reported_crime': 78},
#  {'_id': ObjectId('617b40775dd8891e00990e20'),
#   'crime_month_name': 'May',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1488},
#  {'_id': ObjectId('617b40775dd8891e00990e21'),
#   'crime_month_name': 'May',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3505},
#  {'_id': ObjectId('617b40775dd8891e00990e22'),
#   'crime_month_name': 'May',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 1323},
#  {'_id': ObjectId('617b40775dd8891e00990e23'),
#   'crime_month_name': 'May',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 12},
#  {'_id': ObjectId('617b40775dd8891e00990e24'),
#   'crime_month_name': 'May',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 2477},
#  {'_id': ObjectId('617b40775dd8891e00990e25'),
#   'crime_month_name': 'May',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 91},
#  {'_id': ObjectId('617b40775dd8891e00990e26'),
#   'crime_month_name': 'May',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 277},
#  {'_id': ObjectId('617b40775dd8891e00990e27'),
#   'crime_month_name': 'May',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1023},
#  {'_id': ObjectId('617b40775dd8891e00990e28'),
#   'crime_month_name': 'May',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990e29'),
#   'crime_month_name': 'May',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 86},
#  {'_id': ObjectId('617b40775dd8891e00990e2a'),
#   'crime_month_name': 'May',
#   'primary_type': 'HUMAN TRAFFICKING',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990e2b'),
#   'crime_month_name': 'May',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 37},
#  {'_id': ObjectId('617b40775dd8891e00990e2c'),
#   'crime_month_name': 'May',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 10},
#  {'_id': ObjectId('617b40775dd8891e00990e2d'),
#   'crime_month_name': 'May',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 11},
#  {'_id': ObjectId('617b40775dd8891e00990e2e'),
#   'crime_month_name': 'May',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 4},
#  {'_id': ObjectId('617b40775dd8891e00990e2f'),
#   'crime_month_name': 'May',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 829},
#  {'_id': ObjectId('617b40775dd8891e00990e30'),
#   'crime_month_name': 'May',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 484},
#  {'_id': ObjectId('617b40775dd8891e00990e31'),
#   'crime_month_name': 'May',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 7},
#  {'_id': ObjectId('617b40775dd8891e00990e32'),
#   'crime_month_name': 'May',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 147},
#  {'_id': ObjectId('617b40775dd8891e00990e33'),
#   'crime_month_name': 'May',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 879},
#  {'_id': ObjectId('617b40775dd8891e00990e34'),
#   'crime_month_name': 'May',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 11},
#  {'_id': ObjectId('617b40775dd8891e00990e35'),
#   'crime_month_name': 'May',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990e36'),
#   'crime_month_name': 'May',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 408},
#  {'_id': ObjectId('617b40775dd8891e00990e37'),
#   'crime_month_name': 'May',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 598},
#  {'_id': ObjectId('617b40775dd8891e00990e38'),
#   'crime_month_name': 'May',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 62},
#  {'_id': ObjectId('617b40775dd8891e00990e39'),
#   'crime_month_name': 'May',
#   'primary_type': 'STALKING',
#   'reported_crime': 10},
#  {'_id': ObjectId('617b40775dd8891e00990e3a'),
#   'crime_month_name': 'May',
#   'primary_type': 'THEFT',
#   'reported_crime': 2913},
#  {'_id': ObjectId('617b40775dd8891e00990e3b'),
#   'crime_month_name': 'May',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 792},
#  {'_id': ObjectId('617b40775dd8891e00990e3c'),
#   'crime_month_name': 'November',
#   'primary_type': 'ARSON',
#   'reported_crime': 50},
#  {'_id': ObjectId('617b40775dd8891e00990e3d'),
#   'crime_month_name': 'November',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1337},
#  {'_id': ObjectId('617b40775dd8891e00990e3e'),
#   'crime_month_name': 'November',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3013},
#  {'_id': ObjectId('617b40775dd8891e00990e3f'),
#   'crime_month_name': 'November',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 619},
#  {'_id': ObjectId('617b40775dd8891e00990e40'),
#   'crime_month_name': 'November',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 13},
#  {'_id': ObjectId('617b40775dd8891e00990e41'),
#   'crime_month_name': 'November',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1888},
#  {'_id': ObjectId('617b40775dd8891e00990e42'),
#   'crime_month_name': 'November',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 94},
#  {'_id': ObjectId('617b40775dd8891e00990e43'),
#   'crime_month_name': 'November',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 270},
#  {'_id': ObjectId('617b40775dd8891e00990e44'),
#   'crime_month_name': 'November',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 2009},
#  {'_id': ObjectId('617b40775dd8891e00990e45'),
#   'crime_month_name': 'November',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 3},
#  {'_id': ObjectId('617b40775dd8891e00990e46'),
#   'crime_month_name': 'November',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 63},
#  {'_id': ObjectId('617b40775dd8891e00990e47'),
#   'crime_month_name': 'November',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 34},
#  {'_id': ObjectId('617b40775dd8891e00990e48'),
#   'crime_month_name': 'November',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 13},
#  {'_id': ObjectId('617b40775dd8891e00990e49'),
#   'crime_month_name': 'November',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 7},
#  {'_id': ObjectId('617b40775dd8891e00990e4a'),
#   'crime_month_name': 'November',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 3},
#  {'_id': ObjectId('617b40775dd8891e00990e4b'),
#   'crime_month_name': 'November',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 937},
#  {'_id': ObjectId('617b40775dd8891e00990e4c'),
#   'crime_month_name': 'November',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 507},
#  {'_id': ObjectId('617b40775dd8891e00990e4d'),
#   'crime_month_name': 'November',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990e4e'),
#   'crime_month_name': 'November',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 144},
#  {'_id': ObjectId('617b40775dd8891e00990e4f'),
#   'crime_month_name': 'November',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 942},
#  {'_id': ObjectId('617b40775dd8891e00990e50'),
#   'crime_month_name': 'November',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 4},
#  {'_id': ObjectId('617b40775dd8891e00990e51'),
#   'crime_month_name': 'November',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990e52'),
#   'crime_month_name': 'November',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 47},
#  {'_id': ObjectId('617b40775dd8891e00990e53'),
#   'crime_month_name': 'November',
#   'primary_type': 'RITUALISM',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990e54'),
#   'crime_month_name': 'November',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 756},
#  {'_id': ObjectId('617b40775dd8891e00990e55'),
#   'crime_month_name': 'November',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 66},
#  {'_id': ObjectId('617b40775dd8891e00990e56'),
#   'crime_month_name': 'November',
#   'primary_type': 'STALKING',
#   'reported_crime': 21},
#  {'_id': ObjectId('617b40775dd8891e00990e57'),
#   'crime_month_name': 'November',
#   'primary_type': 'THEFT',
#   'reported_crime': 2957},
#  {'_id': ObjectId('617b40775dd8891e00990e58'),
#   'crime_month_name': 'November',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 777},
#  {'_id': ObjectId('617b40775dd8891e00990e59'),
#   'crime_month_name': 'October',
#   'primary_type': 'ARSON',
#   'reported_crime': 54},
#  {'_id': ObjectId('617b40775dd8891e00990e5a'),
#   'crime_month_name': 'October',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1512},
#  {'_id': ObjectId('617b40775dd8891e00990e5b'),
#   'crime_month_name': 'October',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3416},
#  {'_id': ObjectId('617b40775dd8891e00990e5c'),
#   'crime_month_name': 'October',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 643},
#  {'_id': ObjectId('617b40775dd8891e00990e5d'),
#   'crime_month_name': 'October',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 14},
#  {'_id': ObjectId('617b40775dd8891e00990e5e'),
#   'crime_month_name': 'October',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 2141},
#  {'_id': ObjectId('617b40775dd8891e00990e5f'),
#   'crime_month_name': 'October',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 103},
#  {'_id': ObjectId('617b40775dd8891e00990e60'),
#   'crime_month_name': 'October',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 315},
#  {'_id': ObjectId('617b40775dd8891e00990e61'),
#   'crime_month_name': 'October',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 2026},
#  {'_id': ObjectId('617b40775dd8891e00990e62'),
#   'crime_month_name': 'October',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990e63'),
#   'crime_month_name': 'October',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 68},
#  {'_id': ObjectId('617b40775dd8891e00990e64'),
#   'crime_month_name': 'October',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 53},
#  {'_id': ObjectId('617b40775dd8891e00990e65'),
#   'crime_month_name': 'October',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 20},
#  {'_id': ObjectId('617b40775dd8891e00990e66'),
#   'crime_month_name': 'October',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 12},
#  {'_id': ObjectId('617b40775dd8891e00990e67'),
#   'crime_month_name': 'October',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 11},
#  {'_id': ObjectId('617b40775dd8891e00990e68'),
#   'crime_month_name': 'October',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 998},
#  {'_id': ObjectId('617b40775dd8891e00990e69'),
#   'crime_month_name': 'October',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 624},
#  {'_id': ObjectId('617b40775dd8891e00990e6a'),
#   'crime_month_name': 'October',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 8},
#  {'_id': ObjectId('617b40775dd8891e00990e6b'),
#   'crime_month_name': 'October',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 148},
#  {'_id': ObjectId('617b40775dd8891e00990e6c'),
#   'crime_month_name': 'October',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1061},
#  {'_id': ObjectId('617b40775dd8891e00990e6d'),
#   'crime_month_name': 'October',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 4},
#  {'_id': ObjectId('617b40775dd8891e00990e6e'),
#   'crime_month_name': 'October',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990e6f'),
#   'crime_month_name': 'October',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 66},
#  {'_id': ObjectId('617b40775dd8891e00990e70'),
#   'crime_month_name': 'October',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 756},
#  {'_id': ObjectId('617b40775dd8891e00990e71'),
#   'crime_month_name': 'October',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 82},
#  {'_id': ObjectId('617b40775dd8891e00990e72'),
#   'crime_month_name': 'October',
#   'primary_type': 'STALKING',
#   'reported_crime': 18},
#  {'_id': ObjectId('617b40775dd8891e00990e73'),
#   'crime_month_name': 'October',
#   'primary_type': 'THEFT',
#   'reported_crime': 3418},
#  {'_id': ObjectId('617b40775dd8891e00990e74'),
#   'crime_month_name': 'October',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 806},
#  {'_id': ObjectId('617b40775dd8891e00990e75'),
#   'crime_month_name': 'September',
#   'primary_type': 'ARSON',
#   'reported_crime': 55},
#  {'_id': ObjectId('617b40775dd8891e00990e76'),
#   'crime_month_name': 'September',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1698},
#  {'_id': ObjectId('617b40775dd8891e00990e77'),
#   'crime_month_name': 'September',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3440},
#  {'_id': ObjectId('617b40775dd8891e00990e78'),
#   'crime_month_name': 'September',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 612},
#  {'_id': ObjectId('617b40775dd8891e00990e79'),
#   'crime_month_name': 'September',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 17},
#  {'_id': ObjectId('617b40775dd8891e00990e7a'),
#   'crime_month_name': 'September',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 2167},
#  {'_id': ObjectId('617b40775dd8891e00990e7b'),
#   'crime_month_name': 'September',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 96},
#  {'_id': ObjectId('617b40775dd8891e00990e7c'),
#   'crime_month_name': 'September',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 374},
#  {'_id': ObjectId('617b40775dd8891e00990e7d'),
#   'crime_month_name': 'September',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1172},
#  {'_id': ObjectId('617b40775dd8891e00990e7e'),
#   'crime_month_name': 'September',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 3},
#  {'_id': ObjectId('617b40775dd8891e00990e7f'),
#   'crime_month_name': 'September',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 82},
#  {'_id': ObjectId('617b40775dd8891e00990e80'),
#   'crime_month_name': 'September',
#   'primary_type': 'HUMAN TRAFFICKING',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990e81'),
#   'crime_month_name': 'September',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 34},
#  {'_id': ObjectId('617b40775dd8891e00990e82'),
#   'crime_month_name': 'September',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 20},
#  {'_id': ObjectId('617b40775dd8891e00990e83'),
#   'crime_month_name': 'September',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 14},
#  {'_id': ObjectId('617b40775dd8891e00990e84'),
#   'crime_month_name': 'September',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 15},
#  {'_id': ObjectId('617b40775dd8891e00990e85'),
#   'crime_month_name': 'September',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 921},
#  {'_id': ObjectId('617b40775dd8891e00990e86'),
#   'crime_month_name': 'September',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 558},
#  {'_id': ObjectId('617b40775dd8891e00990e87'),
#   'crime_month_name': 'September',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 3},
#  {'_id': ObjectId('617b40775dd8891e00990e88'),
#   'crime_month_name': 'September',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 157},
#  {'_id': ObjectId('617b40775dd8891e00990e89'),
#   'crime_month_name': 'September',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1054},
#  {'_id': ObjectId('617b40775dd8891e00990e8a'),
#   'crime_month_name': 'September',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 48},
#  {'_id': ObjectId('617b40775dd8891e00990e8b'),
#   'crime_month_name': 'September',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 1},
#  {'_id': ObjectId('617b40775dd8891e00990e8c'),
#   'crime_month_name': 'September',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 66},
#  {'_id': ObjectId('617b40775dd8891e00990e8d'),
#   'crime_month_name': 'September',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 743},
#  {'_id': ObjectId('617b40775dd8891e00990e8e'),
#   'crime_month_name': 'September',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 67},
#  {'_id': ObjectId('617b40775dd8891e00990e8f'),
#   'crime_month_name': 'September',
#   'primary_type': 'STALKING',
#   'reported_crime': 16},
#  {'_id': ObjectId('617b40775dd8891e00990e90'),
#   'crime_month_name': 'September',
#   'primary_type': 'THEFT',
#   'reported_crime': 3618},
#  {'_id': ObjectId('617b40775dd8891e00990e91'),
#   'crime_month_name': 'September',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 831}]
